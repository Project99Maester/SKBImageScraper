# %%
from bs4 import BeautifulSoup
import requests

# %%
searchString='trees'
url='https://www.google.com/search?q={}&source=lnms&tbm=isch&sa=X'.format(searchString)

# %%
header = {
        'User-Agent': "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/43.0.2357.134 Safari/537.36"}
data=requests.get(url,headers=header)
html_data=BeautifulSoup(data.content,'html.parser')

# %%
img_url=[]
for img in html_data.find_all('img',{'class':'rg_i Q4LuWd'}):
    if 'data-src' in img.attrs:
        img_url.append(img['data-src'])

# %%
import os
# os.getcwd()
file_name=os.path.join(os.getcwd(),'download\\{}\\'.format(searchString))

# %%
counter=1
try:
    os.mkdir(file_name)
except Exception:
    pass
for imUrl in img_url:
    if counter>20:
        break
    img=requests.get(imUrl,headers=header)
    with open(file_name+"{}.jpg".format(counter), "wb") as imgs:
        imgs.write(img.content)
    counter+=1

# %%
with open(".\download\image_name.jpg", "wb") as img:
    img.write(we)

# %%
url
# Out:
# 'https://www.google.com/search?q=trees&source=lnms&tbm=isch'

# %%
html_data.prettify()
# Out:
# '<!DOCTYPE html>\n<html dir="ltr" itemscope="" itemtype="http://schema.org/SearchResultsPage" lang="en">\n <head>\n  <base href="https://www.google.com/"/>\n  <meta content="origin" name="referrer"/>\n  <meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" property="image"/>\n  <script data-id="_gd" nonce="bBh0GEmA4CR8zpOlVJ0ivQ">\n   window.WIZ_global_data = {"AY2V6d":true,"DpimGf":false,"EP1ykd":["/_/*","/cameos","/cameos/*","/coronavirus-map","/coronavirus-map/*","/covid19-map","/covid19-map/*","/covid19/exposurenotifications/select","/covid19/exposurenotifications/select/*","/finance","/finance/*","/healthinsurance/immersive","/healthinsurance/immersive/*","/history","/history/*","/local/business","/local/business/*","/local/follow","/local/follow/*","/local/imagery/report","/local/imagery/report/*","/local/pickup","/local/pickup/*","/local/realestate","/local/realestate/*","/localguides","/localguides/*","/maps/notifications/webviews","/maps/notifications/webviews/*","/maps/rpc","/maps/rpc/*","/onlinecare/immersive","/onlinecare/immersive/*","/preferences/notifications","/preferences/notifications/*","/recaptcha/challengepage","/recaptcha/challengepage/*","/search/questions","/search/questions/*","/shopping/ratings","/shopping/ratings/*","/travel/activities","/travel/activities/*","/travel/hotels/s","/travel/hotels/s/*","/wizrpcui","/wizrpcui/*"],"EpwAsb":1606486334437000,"FdrFJe":"9155947596256412283","Im6cmf":"/_/VisualFrontendUi","LVIXXb":1,"LoQv7e":false,"MT7f9b":[],"Og7bYc":"%.@.false]\\n","Qokmvc":true,"QrtxK":"","S06Grb":"","S1NZmd":false,"Yllh3e":"%.@.1606399934436942,24363994,4244808827]\\n","cfb2h":"boq_visualfrontendserver_20201123.05_p0","eNnkwf":"1606399934","eptZe":"/_/VisualFrontendUi/","fPDxwd":[1763433,45695529],"gGcLoe":true,"nQyAE":{"EV8yxc":"0","ZUnjQb":"0","TFtxd":"false","WjMLC":"false","Ix7enf":"false","n7LBcd":"500","HYDafc":"-1.0","YE5Aub":"DEFAULT_DO_NOT_DISPLAY","wTZmyb":"true","xP3jaf":"false","Ldqcce":"false","wuZIkf":"400","D35Vee":"100","XvEDBf":"true","D88Eab":"false","G5i9gc":"0.5","iu6b9":"0","aV0RL":"true","cIQILe":"0","XcrMIc":"300","MfIHqf":"false","A3Czee":"true","znfaGc":"864","wmif7":"400","gKD34":"2500","wgyLtf":"false","eYh19c":"false","GSS1We":"500","iT441e":"TOOLTIP_WITHOUT_SWIPE_ANIMATION","tp4Gi":"2","XWOFRd":"false","n0TQeb":"2500","PccRGf":"true","gaC8Zc":"false","tAt3of":"3","BgZTfd":"150","lrGlid":"DESKTOP_AUTOPLAY","Tnvype":"130","z1MgYd":"true","fWge5b":"0","HjXbFf":"false","biZ5Sd":"5","A1qd8e":"false","LBGwTb":"100","kawmrb":"false","xfx3M":"false","i7fZUe":"false","KTcKId":"false","Wnp79b":"false","AvrhYb":"false","WrYZ7d":"false","YPJcgd":"freeze_then_replay","A85Lb":"true","bwARGe":"true","AoFpWc":"false","vgkWnf":"true","efUU2b":"false","gnkERd":"false","Ilr02d":"false","ewJDhd":"false","LPP0Ke":"false","OEFXhc":"","tBSlob":"false","wcLcde":"false","KDlcdd":"1000","ZL51oe":"false"},"p0fdxb":"AOvVaw3zGFpSqzzKroWdwVcv66Wl","qwAQke":"VisualFrontendUi","qymVe":"ILQKOGficG4-6p8_Q_nIREtu1p0","rtQCxc":-330,"uS02ke":"vre_X87VGtqHz7sP-8iK6A8","vXmutd":"%.@.\\"IN\\",\\"ZZ\\",\\"dcX4sw\\\\u003d\\\\u003d\\"]\\n","w2btAe":"%.@.null,null,\\"\\",false,null,null,true,false]\\n","zChJod":"%.@.]\\n","zvLu9e":"%.@.\\"img\\",\\"gws-wiz-img\\",\\"trees\\",\\"i\\",false,false,null,null,null,null,\\"AIPXvyhVQDYj6faW_UFhg28dbsQy9wqYVQ\\",\\"\\",\\"vre_X87VGtqHz7sP-8iK6A8\\",0,\\"en-US\\",null,null,true,false,null,null,null,null,null,null,null,null,null,\\"/complete/deleteitems?deltok\\\\u003d$DELTOK\\\\u0026client\\\\u003d$CLIENT\\\\u0026delq\\\\u003d$DELQUERY\\",null,null,null,null,null,null,false]\\n"};\n  </script>\n  <script nonce="bBh0GEmA4CR8zpOlVJ0ivQ">\n   (function(){/*\n\n Copyright The Closure Library Authors.\n SPDX-License-Identifier: Apache-2.0\n*/\n\'use strict\';var a=!1,e=window,l=e.performance,n=m();e.cc_latency_start_time=l&&l.now?0:l&&l.timing&&l.timing.navigationStart?l.timing.navigationStart:n;function m(){return l&&l.now?l.now():(new Date).get ...
